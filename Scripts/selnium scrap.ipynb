# %%
from selenium import webdriver
import time
import re
import csv
import string

def isEnglish(s):
    try:
        s.encode('ascii')
    except UnicodeEncodeError:
        return False
    else:
        return True

driver = webdriver.Chrome('C:\webdrivers\chromedriver')
yt_link = input("Link to Youtube video: ")
#print("-------------------------------------------------------------------------------------------------------------------")
#driver.get(yt_link)
driver.get("https://www.youtube.com/watch?v="+yt_link)
driver.maximize_window()
time.sleep(5)
title = driver.find_element_by_xpath('//*[@id="container"]/h1/yt-formatted-string').text
#print("Video Title: " + title)
#print("-------------------------------------------------------------------------------------------------------------------")

comment_section = driver.find_element_by_xpath('//*[@id="comments"]')
driver.execute_script("arguments[0].scrollIntoView();", comment_section)
time.sleep(7)

last_height = driver.execute_script("return document.documentElement.scrollHeight")
while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")

    # Wait to load page
    time.sleep(2)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.documentElement.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")

emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  
                           u"\U0001F300-\U0001F5FF"
                           u"\U0001F680-\U0001F6FF"
                           u"\U0001F1E0-\U0001F1FF"
                           "]+", flags=re.UNICODE)

name_elems=driver.find_elements_by_xpath('//*[@id="author-text"]')
comment_elems = driver.find_elements_by_xpath('//*[@id="content-text"]')
num_of_names = len(name_elems)
for i in range(num_of_names):
   # username = name_elems[i].text    # .replace(",", "|")
    # username = emoji_pattern.sub(r'', username)
    # username = str(username).replace("\n", "---")
    comment = comment_elems[i].text    # .replace(",", "|")
    # comment = emoji_pattern.sub(r'', comment)
    # comment = str(comment).replace("\n", "---")
    
    #if isEnglish(comment) == False:
     #   comment = "NOT ENGLISH"
        
    print(  comment) # comment.translate({ord(i):None for i in '' if i not in string.printable})
driver.close()
# Out:
# Link to Youtube video: gK1qlo0OsSc
# Which was your your favorite? 😂🤯
# Estan son las personas que hablan español
# 👇
# 1:36 CAN'T STOP LAUGHING 😂😂😂
# 1:29 he sounds like penny wise
# 2:35 it’s so funny 😂 🤣🤣
# 4:30 ngakakkk
# The Reality turned into a try not to laugh😂
# 3:08 he sounds like a chicken kinda
# 2:35 me when I'm nervous to talk to my crush
# Esse é o comentário em português que vc tanto procura
# 2:19 the best part 😂
# Who's watching him at tiktok
# 👇
# Hi, I can speak English and Portuguese and Spanish
# 0:38 I thought he spit on me
# The problem with me is, I couldn’t make a beat with those effects but I can make the sound (etc. zipper)
# Bro I can beat you in a minute in60 sec and my sister can’t even do it WOW it’s funny 🤣🤣🤣 Wow your the best and the beast and it’s so funny your friend can’t do it’s but some of it it’s so always like that he does p sc p sc p sc sp scars CSR XX.
# this is how much spencer is good at beatboxing
# 👇🏻
# 0:33 my brother when he is trying to drop the bass
# 04:37 OMG🤣🤣🤣🤣
# 2:05 its not a dog already its a rooster 😂😂
# Spencer's laugh is killing me
# Who loves BeatBoxing?!❤🔥
# 4:26 i love this one were he sprayed his friend or brother
# 2:09 Its my favorite Demon bass the sound ouououou
# Omg omg omg I was laughing so hard at the end when the blondie sprayed the silly string on the black hair dude damn I was laughing so hard that I felL of my bed but geez it hurts.... btw love your videos even tho I just stared watching it ....I think u beat really good
# 4:36 haha
# The siren one that was cool
# I ...Brasil kk no inglês 😂😂😂 i love you 😍💜
# It's so funny when joey do all the reality sounds =D
# 3:22
#
# I love it.
# He literally said he’s not human  so he’s alien or a robot
# The reality is so funny make funny moments of beatboxing
# 2:21 melhor parte
# I am watching from India 🇮🇳🇮🇳
# 1:30
# Those laughs killed me 🤣🤣
# Am i the only person who got anxious when he threw the plate.
# HELOLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLLL FRENDE
# 4:37 HAHAHAHAHA
# 2:38 "yow wt.."
# 0:59 I was waiting for the zipper to get caught on something
