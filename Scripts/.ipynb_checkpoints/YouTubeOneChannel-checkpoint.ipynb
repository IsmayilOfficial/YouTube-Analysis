# %%
import urllib.request
from bs4 import BeautifulSoup as bs
import locale
import re
import pandas as pd
import matplotlib as plt
# %matplotlib inline

# %%
url = "https://www.youtube.com/channel/UCeo3JwE3HezUWFdVcehQk9Q/videos?sort=p&flow=grid&view=0"
response = urllib.request.urlopen(url)
html_cont = response.read()
soup = bs(html_cont,'html.parser',from_encoding = "UTF-8")
print(soup.prettify())
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-15-ebb3f54cf612> in <module>
#       1 url = "https://www.youtube.com/channel/UCeo3JwE3HezUWFdVcehQk9Q/videos?sort=p&flow=grid&view=0"
#       2 response = urllib.request.urlopen(url)
# ----> 3 html_cont = response.read()
#       4 soup = bs(html_cont,'html.parser',from_encoding = "UTF-8")
#       5 #print(soup.prettify())
#
# ~\Anaconda3\lib\http\client.py in read(self, amt)
#     462
#     463             if self.chunked:
# --> 464                 return self._readall_chunked()
#     465
#     466             if self.length is None:
#
# ~\Anaconda3\lib\http\client.py in _readall_chunked(self)
#     572                 if chunk_left is None:
#     573                     break
# --> 574                 value.append(self._safe_read(chunk_left))
#     575                 self.chunk_left = 0
#     576             return b''.join(value)
#
# ~\Anaconda3\lib\http\client.py in _safe_read(self, amt)
#     618         s = []
#     619         while amt > 0:
# --> 620             chunk = self.fp.read(min(amt, MAXAMOUNT))
#     621             if not chunk:
#     622                 raise IncompleteRead(b''.join(s), amt)
#
# ~\Anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~\Anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# ~\Anaconda3\lib\ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# OSError: [WinError 10051] A socket operation was attempted to an unreachable network

# %%
viewlist = []
infos = soup.find_all("ul" ,class_="yt-lockup-meta-info")
import locale
locale.setlocale(locale.LC_ALL,"en_us.UTF-8")
for info in infos: 
    temp =  re.findall("((\d+,)+\d+)$", info.li.text)[0][0] 
    temp2num = locale.atoi(temp)
    viewlist.append(temp2num)
viewseries =  pd.Series(viewlist)
channelInfo = pd.DataFrame(viewseries,columns=["View"])
channelInfo.head(5)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-84cb3c8d16b4> in <module>
#       4 locale.setlocale(locale.LC_ALL,"en_us.UTF-8")
#       5 for info in infos:
# ----> 6     temp =  re.findall("((\d+,)+\d+)$", info.li.text)[10000][10000]
#       7     temp2num = locale.atoi(temp)
#       8     viewlist.append(temp2num)
#
# IndexError: list index out of range

# %%
channelInfo.describe()
# Out:
#                View
# count  3.000000e+01
# mean   6.559642e+05
# std    2.360924e+05
# min    4.489540e+05
# 25%    4.985680e+05
# 50%    6.051985e+05
# 75%    7.073570e+05
# max    1.500003e+06

# %%
channelInfo.plot.box()

# %%
channelInfo.plot.hist()

# %%
titleList = []
timeList=[]
urlList=[]
infos = soup.find_all("h3" ,class_="yt-lockup-title")
for info in infos:
    titleList.append(info.a["title"])
    urlList.append(re.findall(r"\?v=(.{11})",info.a["href"])[0])
    m =  int(re.findall("(\d+) 分鐘",info.span.text)[0]) if len(re.findall("(\d+) 分鐘",info.span.text))>0 else 0
    s =  int(re.findall("(\d+) 秒",info.span.text)[0]) if len(re.findall("(\d+) 秒",info.span.text))>0 else 0
    timeList.append(m*60+s)
titleSeries = pd.Series(titleList)
#titleSeries.head()
timeSeries = pd.Series(timeList)
urlSeries = pd.Series(urlList)
#timeSeries.head()
channelInfo["Title"]=titleSeries
channelInfo["Time"]=timeSeries
channelInfo["url"]=urlSeries
channelInfo.head(30)
# Out:
#        View                                              Title  Time  \
# 0   1500003                                         我要離開這個頻道了。   290
# 1   1248680  完整・全解析最有效背單字法 // Comprehensive Method of Vocab...   660
# 2   1023342  3個訣竅講出一口自然流利英文 // 3 Tips To Sound More Like A ...   393
# 3    803355               阿滴英文｜挑戰! 你聽得懂日本英文嗎? feat. Ryu & Yuma   780
# 4    765904                    阿滴英文｜挑戰15分鐘完勝學測英文考題! 阿滴vs滴妹大對決!   530
# 5    726760                 阿滴英文｜史上最簡單的英文猜謎遊戲 feat. 聖結石 聖嫂Dodo   600
# 6    729241               阿滴英文｜這群人神作超瞎翻唱! 英文翻譯有及格嗎? feat. 展榮展瑞   720
# 7    712448   開箱! YouTubers 交換禮物大亂鬥 feat. 白癡公主/囧星人/林辰Buchi/壹加壹   452
# 8    692084   滴妹翻唱千年之戀 MV // Crown Cover - A Thousand Years MV   299
# 9    689762                阿滴英文｜字典裡居然都有! 跟放火一起學新加坡式英文 feat. 放火   540
# 10   671780                               阿滴問與答#6 滴妹跟阿滴誰比較受歡迎？   308
# 11   654510              阿滴英文｜你好carry! 不要gank我! 打英雄聯盟LOL必懂英文單字   355
# 12   647975  日常英文單字#4【星巴克咖啡】// English Vocabulary: Starbuck...   326
# 13   617754  英文歌分享#4 "Faded" // English Song Spotlight (Ala...   444
# 14   606925                  阿滴英文｜Pizza? Police? 這10個單字發音該怎麼唸？   395
# 15   603472  大學甄試入學超殺英文自介 // How to Kill Professors with Yo...   370
# 16   573154  阿滴英文｜英文流行歌曲分享 - "Something Just Like This" The...   408
# 17   528411      阿滴英文｜Killing spree? Pentakill? 秒懂英雄聯盟連殺系統英文單字   408
# 18   527417                  50 Facts About Crown // 關於滴妹的50件事   407
# 19   519660       10個一定得知道的常用英文句子 // 10 Common English Phrases   296
# 20   510493  英文歌分享#6 "Closer" // English Song Spotlight (Th...   575
# 21   527004             阿滴英文｜美國才有賣的糖果? 又是滴妹最愛的試吃時光! feat. 白癡公主   660
# 22   494593                                       關於我要離開頻道這件事。   232
# 23   489149       開箱! YouTubers 聖誕交換禮物 feat. HowHow / 林辰 / 壹加壹   540
# 24   489816                    【生日特輯】阿滴的一天 feat. 數不清的YouTubers   312
# 25   487476  台灣人常犯的英文錯誤#1 // Common English Mistakes in Taiwan   379
# 26   480716  英文歌分享#2 "Blank Space" // English Song Spotligh...   382
# 27   456241  10句常用英文#6【餐廳點餐篇】// 10 English Phrases: Orderin...   353
# 28   451848                阿滴英文｜高中生注意! 尊遇到的英文學習問題 feat. 人生肥宅x尊   500
# 29   448954  神速進步 看影片學英文方法 // Improving Your English Quickl...   412
#
#             url
# 0   lrgCrpJCh34
# 1   gkVpNq4-wqs
# 2   6JeTQb3YKYY
# 3   beRCHzxz7cM
# 4   l95ey_v5XTg
# 5   Al-cLgpvu_4
# 6   uT4V2fbWFC4
# 7   HlyD08vTju0
# 8   oeo0m64_iwY
# 9   VnCZEkl6Cr8
# 10  nLh5EJsmrgc
# 11  VG_njlfMXhk
# 12  KVlYn4Fnd6k
# 13  Q15GXH4E4pw
# 14  EP8m3P_FiyU
# 15  9kqPqGwyvK0
# 16  PAUQrYgeamg
# 17  7Gp_D1J2aN0
# 18  GdgNYMD0pNQ
# 19  X84jRQcEiVc
# 20  cIVx5Yxzl6E
# 21  ymqCHolbGtQ
# 22  Ait5axzxtNs
# 23  AZP_LXlWglY
# 24  BNj7J3u8u1Q
# 25  Tsdyv4Uba7s
# 26  RuMD2fzja2Y
# 27  PTPxl5Jz5NM
# 28  02Jl44Mj0fM
# 29  mLscQfiVqlg

# %%
channelInfo.to_csv("Output.csv",encoding='utf-8')
