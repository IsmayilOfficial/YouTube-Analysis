# %%
from bs4 import BeautifulSoup
import re
import requests
import csv
import time
import json

# version 1.1 added handling of youtube.com/channel/
#  to already handling of youtube.com/user based channels

# NOTE: url gets to youtube are throttled to 3 seconds between requests
# this is an ad hoc attempt to look like a human to youtube
# so youtube does not start limiting access
wait_between_requests = 3

""" scrape youtube channel to build table of contents html file and 
    csv of video information for excel file
    note this code has a slow down delay to meet youtube terms of use
"""

# set youtube channel name here
channel_name = 'ZONEofTECH'


youtube_base = 'https://www.youtube.com/'
# others to try
#  gotreehouse  howgrowvideo  gjenkinslbcc howgrowvideo
# by channel name:
#  UCu8YylsPiu9XfaQC74Hr_Gw  UCn34N9fj3x92kOGnQQdHkAQ
# UCH4aPBlmmW1Vgs0ykktCMUg

parent_folder = ''  # users or channel or empty


def get_soup(url):
    """open url and return BeautifulSoup object, 
       or None if site does not exist"""
    
    result = requests.get(url)
    if result.status_code != 200: return None
    time.sleep(wait_between_requests)  # slow down to human speed
    return BeautifulSoup(result.text, 'html.parser')


def channel_section_links(channel_name):
    """list of 
       { 'title': <section title>, 
         'link': <url to section play lists> 
       }"""

    global parent_folder

    soup = get_soup(f'{youtube_base}/user/{channel_name}/playlists')
    if soup is None or 'This channel does not exist.' in soup.text:
        url = f'{youtube_base}/channel/{channel_name}/playlists'
        soup = get_soup(url)
        if soup is None or 'This channel does not exist.' in soup.text:
            raise ValueError(
                'The channel does not exists: ' + channel_name)
        parent_folder = 'channel/'

    play_list_atags = \
        soup.find_all('a',
                      {'href': re.compile(f'{channel_name}/playlists')})
    # filter out non user play lists next
    elements = [{'title': x.text.strip(),
                 'link': fix_url(x['href'])} for x in play_list_atags
                if x.span and
                ('shelf_id=0' not in x['href'])]

    # no sections, make up no sections section with default link
    if len(elements) == 0:
        url = f'{youtube_base}{parent_folder}{channel_name}/playlists'
        elements = [ {'title': 'no sections', 'link': url}]
        # i.e.  https://youtube.com/gotreehouse/playlists
    return elements


def fix_url(url):  # correct relative urls back to absolute urls
    if url[0] == '/':
        return youtube_base + url
    else:
        return url


def get_playlists(section):
    """returns list of list of
    { 'title': <playlist tile>, <link to all playlist videos> }"""
    global parent_folder
    print(f"  getting playlists for section: {section['title']}")

    soup = get_soup(section['link'])
    if soup is None: # no playlist, create dummy with default link
        url = f'{youtube_base}{parent_folder}{channel_name}/videos'
        return [
           {'title': 'No Playlists', 'link':url }]
    atags = soup('a', class_='yt-uix-tile-link')

    playlists = []
    for a in atags:  # find title and link
        title = a.text
        if title != 'Liked videos': # skip these
            url = fix_url(a['href'])
            playlists.append({'title': title, 'link': url})

    if not playlists:  # no playlists
        url = f'{youtube_base}/{parent_folder}{channel_name}/videos'
        return [{'title': 'No Playlists', 'link': url}]

    return playlists

def parse_video(vurl):
    # return dict of
    # title, link, views, publication_date,
    # description, short_link, likes, dislikes

    d = {'link': vurl, 'views': None, 'short_link': vurl,
         'likes': None, 'dislikes': None}

    # now get video page and pull information from it
    vsoup = get_soup(vurl)

    o = vsoup.find('title')
    vtitle = o.text.strip()
    xending = ' - YouTube'
    d['title'] = vtitle[:-len(xending)] \
        if vtitle.endswith(xending) else vtitle
    print(f"      processing video '{d['title']}'" )

    # o is used in the code following to
    # catch missing data targets for scrapping
    o = vsoup.find('div', class_='watch-view-count')
    if o:
        views = o.text
        d['views'] = ''.join(c for c in views if c in '0123456789')

    o = vsoup.find('strong', class_='watch-time-text')
    d['publication_date'] = \
        o.text[len('Published on ') - 1:] if o else ''

    o = vsoup.find('div', id='watch-description-text')
    d['description'] = o.text if o else ''

    o = vsoup.find('meta', itemprop='videoId')
    if o:
        vid = o['content']
        d['short_link'] = f'https://youtu.be/{vid}'

    o = vsoup.find('button',
                   class_='like-button-renderer-like-button')
    if o:
        o = o.find('span', class_='yt-uix-button-content')
        d['likes'] = o.text if o else ''

    o = vsoup.find('button',
                   class_='like-button-renderer-dislike-button')
    if o:
        o = o.find('span', class_='yt-uix-button-content')
        d['dislikes'] = o.text if o else ''

    return d


def add_videos(playlist):
    """find videos in playlist[link]
    and add their info as playlist[videos] as list"""
    surl = playlist['link']
    soup = get_soup(surl)
    print(f"    getting videos for playlist: {playlist['title']}")

    videos = []

    # items are list of video a links from list
    items = soup('a', class_='yt-uix-tile-link')

    # note first part of look get info from playlist page item,
    # and the the last part opens the video and gets more details
    if len(items) > 0:
        for i in items:
            d = dict()
            vurl = fix_url(i['href'])
            t = i.find_next('span', {'aria-label': True})
            d['time'] = t.text if t else 'NA'

            d.update(parse_video(vurl))
            videos.append(d)

    else:  # must be only one video
        d = {'time': 'NA'}
        d.update(parse_video(surl))
        videos.append(d)

    # add new key to this playlist of list of video infos
    playlist['videos'] = videos
    print()


def tag(t,c):
    return f'<{t}>{c}</{t}>' # return html tag with content


def link(text, url): # return a tag with content and link
    return f'<a href="{url}">{text}</a>'


def html_out(channel, sections):
    """create and write channel_name.html file"""
    title = f'YouTube Channel {channel}'
     

    f = open(f'{channel}.html','w',encoding="utf-8")
    template = ('<!doctype html>\n<html lang="en">\n<head>\n'
                '<meta charset="utf-8">'
                '<title>{}</title>\n</head>\n'
                '<body>\n{}\n</body>\n</html>')

    parts = list()
    parts.append(tag('h1', title))

    for s in sections:
        parts.append(tag('h2',link(s['title'], s['link'])))
        for pl in s['playlists']:
            parts.append(tag('h3', link(pl['title'], pl['link'])))
            if len(pl) == 0:
                parts.append('<p>Empty Playlist</p>')
            else:
                parts.append('<ol>')
                for v in pl['videos']:
                    t = '' if v['time'] == 'NA' else f" ({v['time']})"
                    parts.append(tag('li', link(v['title'],
                                     v['short_link']) + t))
                parts.append('</ol>')
    f.write(template.format(channel, '\n'.join(parts)))
    f.close()


def csv_out(channel, sections):
    """ create and output channel_name.csv
    file for import into a spreadsheet or DB"""
    headers = ('channel,section,playlist,video,'
               'link,time,views,publication date,'
               'likes,dislikes,description').split(',')

    with open(f'{channel}.csv', 'w', encoding="utf-8") as csv_file:
        csvf = csv.writer(csv_file, delimiter=',')
        csvf.writerow(headers)
        for section in sections:
            for playlist in section['playlists']:
                for video in playlist['videos']:
                    v = video
                    line = [channel,
                            section['title'],
                            playlist['title'],
                            v['title']]
                    line.extend([v['short_link'],
                                 v['time'], v['views'],
                                 v['publication_date'],
                                 v['likes'], v['dislikes'],
                                 v['description']])
                    csvf.writerow(line)

def process_channel(channel_name):
    sections = channel_section_links(channel_name)
    for section in sections:
        section['playlists'] = get_playlists(section)
        for playlist in section['playlists']:
            add_videos(playlist)
    return sections


if __name__ == '__main__':
    # find channel name by going to channel
    # and picking last element from channel url
    # for example my channel url is:
    #   https://www.youtube.com/user/gjenkinslbcc
    # my channel name is gjenkinslbcc in this url
    # this is set near top of this file
    # if the channel is of the form:
    # https://www.youtube.com/channel/xyz then supply xyz

    print(f'finding sections for youtube.com {channel_name}')
    sections = process_channel(channel_name)

    # save sections structure to json file
    with open(f'{channel_name}.json','w') as f:
        f.write(json.dumps(sections, sort_keys=True, indent=4))

    html_out(channel_name, sections)  # create web page of channel links

    # create a csv file of video info for import into spreadsheet
    csv_out(channel_name, sections)

    print(f"Program Complete,\n  '{channel_name}.html' and"
          f" '{channel_name}.csv' have been" 
          f" written to current directory")
    # 3456789012345678901234567890123456789012345678901234567890123456789012345678901234567890
    #        1         2         3         4         5         6         7         8         9
# Out:
# finding sections for youtube.com ZONEofTECH
#   getting playlists for section: no sections
#     getting videos for playlist: TOP X Things You Didn't Know
#       processing video 'NEW iPad Pro & MacBook Air (2020) - 25 Things You Didn't Know!'
#       processing video 'The BEST Smartwatch You Didn't Know About?'
#       processing video 'PS5 (2020) - 25 THINGS You DIDN'T Know!'
#       processing video 'Samsung Galaxy Z Flip - 30 THINGS You DIDN'T Know!'
#       processing video 'Samsung Galaxy S20 - 40 Things You Didn't Know!'
#       processing video 'TOP Apple Products of 2019!'
#       processing video 'MacBook Pro 16" - 30 Things You Didn't Know!'
#       processing video 'YouTube'
#       processing video 'iPad 2019 – 20 Things You Didn’t Know!'
#       processing video 'Apple Watch Series 5 - 20 Things You Didn't Know!'
#       processing video 'iPhone 11 & 11 Pro - 40 Things You Didn't Know!'
#       processing video 'Apple iPhone 11 Pro Event - 13 Things to Expect!'
#       processing video 'Samsung Galaxy Note 10 - 30 Things You Didn't Know!'
#       processing video 'NEW MacBook Pro & MacBook Air (2019) - 20 Things You Didn't Know!'
#       processing video 'NEW MacBook Pro & MacBook Air (2019) - 20 Things You Didn't Know!'
#       processing video 'iOS 13 - Top 40 BEST NEW Features!'
#       processing video 'Mac Pro 2019 - 35 Things You Didn't Know!'
#       processing video 'MacBook Pro 2019 - 20 Things You Didn't Know!'
#       processing video 'AirPods 2 - 20 Things You Didn't Know!'
#       processing video 'iMac & iMac Pro (2019) - 20 Things You Didn't Know!'
#       processing video 'iPad Air 3 & iPad Mini 5 - 30 Things You Didn't Know!'
#       processing video 'Samsung Galaxy Fold - 20 Things You Didn't Know!'
#       processing video 'Samsung Galaxy S10 - 30 Things You Didn't Know!'
#       processing video 'TOP 10 Tech of CES 2019!'
#       processing video 'Galaxy S10, PS5, New Mac Pro - TOP 10 Upcoming Tech for 2019!'
#       processing video 'TOP BEST Smartphones (2018) - Budget, Mid-Range & High-End!'
#       processing video 'TOP TECH GIFTS (2018) - 17 AWESOME gadgets!'
#       processing video 'NEW Mac Mini - 15 Things You Didn't Know!'
#       processing video 'MacBook Air (2018) - 20 Things You Didn't Know!'
#       processing video 'iPad Pro (2018) - 30 Things You Didn't Know!'
#       processing video 'Google Pixel 3 - 25 Things You Didn't Know!'
#       processing video 'iPhone XR - Watch This Before Buying!'
#       processing video 'iPhone XS & XS Max - 30 Things You Didn't Know!'
#       processing video 'Apple Watch 4 - 30 Things You Didn't Know!'
#       processing video 'iPhone XR - 30 Things You Didn't Know!'
#       processing video '30+ Apple Inconsistencies AFTER Steve Jobs!'
#       processing video 'Samsung Galaxy Note 9 - 12 THINGS YOU NEED TO KNOW!'
#       processing video 'NEW Samsung Galaxy Tab S4 - 12 Things You Didn't Know!'
#       processing video 'MacBook Pro 2018 - 20 Things You Didn't Know!'
#       processing video 'macOS 10.14 Mojave - REVIEW!'
#       processing video 'iOS 12 - TOP 35 BEST NEW Features!'
#       processing video 'Apple's TOP SECRET Project!'
#       processing video 'iOS 12 - 15+ Features We Need!'
#       processing video 'YouTube'
#       processing video 'NEW iPad (2018) - Everything You Need to Know!'
#       processing video 'Samsung Galaxy S9 - 15 Things You Didn't Know!'
#       processing video 'Apple HomePod - 12 Things You NEED to KNOW before BUYING!'
#       processing video 'TOP 5 BEST Laptops (early 2018)'
#       processing video 'iOS 12 - TOP 12 Features WE NEED!'
#       processing video 'TOP 10 UPCOMING Smartphones in 2018'
#       processing video 'iPhone 2018 - TOP 10 Features We NEED!'
#       processing video 'YouTube'
#       processing video 'TOP 10 BEST Smartphone Designs (2017)'
#       processing video 'iPhone X - TOP 25 Tips & Tricks You NEED to KNOW!'
#       processing video 'iPhone X - TOP 25 BEST Features!'
#       processing video 'Apple TV 4K - 20 Things You Need to Know!'
#       processing video 'iPhone 8 & 8 Plus - 25 Things You Didn't Know!'
#       processing video 'Apple Watch 3 - 25 Things You Didn't Know!'
#       processing video 'iPhone X - 35 Things You Didn't Know!'
#       processing video 'iPhone X - TOP 20 Upcoming Features!'
#       processing video 'YouTube'
#       processing video 'Xbox One X - 15 Things You Didn't Know!'
#       processing video 'MacBook Pro 2017 - 13 Things You Didn't Know!'
#       processing video 'iPad Pro 2 (2017) - 10 Things You NEED to KNOW!'
#       processing video 'iOS 11 - TOP 35+ BEST NEW Features!'
#       processing video 'Samsung Galaxy S8 - 30 THINGS You Didn't Know!'
#       processing video 'NEW iPad 9.7 (2017) - 15 THINGS You Didn't Know!'
#       processing video 'Samsung Galaxy S8 - TOP 5 BEST New Features!'
#       processing video 'TOP 5 - BEST Apple Products! (2016)'
#       processing video 'TOP 10 iPhone 8 - Leaks & Rumors!'
#       processing video 'iOS 10 Beta 5 - TOP 12 NEW Features!'
#       processing video 'iOS 10 Beta 4 - TOP NEW Features!'
#       processing video 'iOS 10 (Beta 3) - TOP 20 Features & Secrets!'
#       processing video 'Apple Watch OS 3 - TOP 20 NEW Features!'
#       processing video 'iOS 10 Beta 2 - TOP 20 NEW Features!'
#       processing video 'iOS 10 - TOP 30 FEATURES Review!'
#       processing video 'Samsung Galaxy S7 - 5 Things you NEED to know BEFORE buying!'
#       processing video 'iPad Pro 9.7 - 5 Things to know BEFORE buying!'
#       processing video 'NEW Apple TV - 5 Things you need to know!'
#       processing video 'YouTube'
#       processing video 'iPhone 6S - 5 Things you need to know!'
#       processing video 'HTC One M9 - TOP 5 Worst Features!'
#       processing video 'Apple Watch: TOP 5 Features!'
#       processing video 'HTC One M9 - TOP 5 BEST Features!'
#       processing video 'TOP 5 - Most Innovative CES 2015 Tech!'
#       processing video 'TOP 5 - HTC One (M8) FEATURES'
#       processing video 'TOP 5 - Apple iWatch CONCEPTS'
#       processing video 'Samsung Galaxy Note 3 TOP FEATURES - September 2013 Unpacked Event'
#       processing video 'BEST Samsung Galaxy S4 FEATURE | My favourite S4 feature'
#       processing video 'Top 5 EPIC iOS 7 Concepts!'
#       processing video 'YouTube'
#
#     getting videos for playlist: Unboxings & First Impressions
#       processing video 'The BEST Smartwatch You Didn't Know About?'
#       processing video 'The Weightless 17-inch Laptop!'
#       processing video '16" MacBook Pro - My Thoughts'
#       processing video 'AirPods Pro - Unboxing, Noise Cancelling, Sound Test & More!'
#       processing video 'Google Pixel 4 & Pixel 4 XL - UNBOXING & Impressions!'
#       processing video 'OnePlus 7T PRO Impressions - BEST Android Phone of 2019?'
#       processing video 'Apple Watch 5 – The Watch we’ve ALL been waiting for!'
#       processing video 'iPhone 11 – THIS is the iPhone to Get!'
#       processing video 'iPhone 11 PRO - Unboxing, Camera Test & My Thoughts!'
#       processing video 'iPhone 11 PRO - Unboxing, Camera Test & My Thoughts!'
#       processing video 'iPhone 11 Pro Leaks | Pixel 4 Hands-On | Note 10 Impressions & more -  ZONEofTECH NEWS #22'
#       processing video 'OnePlus 7 Pro - UNBOXING & My 1 Week Experience!'
#       processing video 'YouTube'
#       processing video 'iPad Air 3 (2019) - My 72 Hour Experience!'
#       processing video 'iPad Mini (2019) - My 72 Hour Experience!'
#       processing video 'YouTube'
#       processing video 'Xiaomi sent over this MYSTERY BOX!'
#       processing video 'YouTube'
#       processing video 'MacBook Air 2018 - Is it REALLY worth it?'
#       processing video 'iPad Pro 2018 - Watch This BEFORE Buying!'
#       processing video 'iPhone XR - BEST or WORST iPhone yet?'
#       processing video 'Google Pixel 3 XL - My 2 Week Review!'
#       processing video 'Google Home Hub REVIEW - The BEST Smart Home Assistant?'
#       processing video 'Surface Pro 6 vs Surface Laptop 2 - My 1 Week Experience!'
#       processing video 'Call of Duty Black Ops 4 - MYSTERY BOX Edition Unboxing!'
#       processing video 'Apple Watch 4 - My 48 Hour Experience!'
#       processing video 'iPhone XS Max - My NEW Daily Driver?'
#       processing video 'iPhone XS (GOLD) - Unboxing & Initial Review!'
#       processing video 'MYSTERY Package from Google!'
#       processing video 'NEW 2018 iPhone Models - Hands On!'
#       processing video 'Google Pixel 3 (2018) - FIRST LOOK!'
#       processing video 'iPad X (2018) - FIRST LOOK!'
#       processing video 'YouTube'
#       processing video 'YouTube'
#       processing video 'The LIMITED EDITION OnePlus 5T!'
#       processing video 'NEW iPad 2018 - UNBOXING & Initial REVIEW!'
#       processing video 'Samsung Galaxy S9 Plus (CORAL BLUE) - Unboxing & Initial Review!'
#       processing video 'Samsung Galaxy S9 - Unboxing & Initial Review!'
#       processing video 'Samsung Galaxy S9 Clone - Unboxing!'
#       processing video 'Apple HomePod - Unboxing & Initial Review!'
#       processing video 'MYSTERY Package from GOOGLE!'
#       processing video 'OnePlus 5T - Unboxing & Initial Review'
#       processing video 'iPhone X - UNBOXING & INITIAL REVIEW!'
#       processing video 'YouTube'
#       processing video 'NEW Apple TV 4K - Unboxing & Initial Review!'
#       processing video 'Apple Watch 3 (LTE) - Unboxing & Initial Review!'
#       processing video 'iPhone 8 Plus - UNBOXING & Initial Review!'
#       processing video 'iPhone 8 Gold - UNBOXING & Initial Review!'
#       processing video 'iPhone X CASES - First Look!'
#       processing video 'Samsung Galaxy Note 8 CLONE - Unboxing & Review!'
#       processing video 'iPhone X CLONE - Unboxing & Review!'
#       processing video 'Samsung Galaxy S8 - UNBOXING & Initial REVIEW!'
#       processing video 'Samsung Galaxy S8 FAKE - Unboxing & Hands-On Impressions!'
#       processing video 'Apple Watch 2 - Unboxing & Initial Review! (Black Stainless Steel)'
#       processing video 'Google Pixel XL - Unboxing & Review (after 3+ weeks)!'
#       processing video 'NEW MacBook Pro 2016 - Unboxing & Initial Review!'
#       processing video 'iPhone 7 Plus - EPIC Unboxing & First Impressions!'
#       processing video 'YouTube'
#       processing video 'iPad Pro 9.7 - Unboxing & First Impressions!'
#       processing video 'iPhone SE - Unboxing & First Impressions!'
#       processing video 'Samsung Galaxy S7 (Edge) - Unboxing & First Impressions!'
#       processing video 'iPad Pro - Unboxing & First Impressions!'
#       processing video 'NEW iMac 5K (Late 2015) - Unboxing & First Impressions!'
#       processing video 'iPhone 6S & 6S Plus - First Impressions!'
#       processing video 'EPIC iPhone 6S & 6S Plus Unboxing!'
#       processing video 'Apple iPad Mini 4 - Unboxing & First Impressions!'
#       processing video 'YouTube'
#       processing video 'NEW iPod Touch (6th generation) - EPIC Unboxing & First Impressions!'
#       processing video 'NEW MacBook 12" (2015) - Unboxing & First Impressions'
#       processing video 'NEW LG G4 -  Unboxing & Initial Review!'
#       processing video 'Apple Watch - Unboxing and First Impressions!'
#       processing video 'HTC One M9: Unboxing and First Impressions!'
#       processing video 'NEW MacBook 12 inch - First Impressions!'
#       processing video 'Google Nexus 9 - Unboxing & First Impressions (Initial Review)'
#       processing video 'iPad Mini 3: Unboxing & First Impressions'
#       processing video 'iPad Air 2: Unboxing & First Impressions'
#       processing video 'iPhone 6 Plus (Gold) - Unboxing & First Impressions'
#       processing video 'Alien: Isolation - Nostromo Edition Steelbook (PS4) - Unboxing & Gameplay'
#       processing video 'iPhone 6 - EPIC Unboxing, DEMO & New Features!'
#       processing video 'YouTube'
#       processing video 'NEW LG G Watch (Android on your Watch) - Unboxing & First Look'
#       processing video 'NEW 2014 Sony Playstation 4 (PS4) Infamous Bundle - EPIC Unboxing (4K UltraHD)'
#       processing video 'NEW 2014 HTC One (M8) - Unboxing, First Look and Demo'
#       processing video 'NEW Sphero 2.0 - Unboxing (Intelligent robotic ball for iOS and Android)'
#       processing video 'New Retina MacBook Pro 15 inch Haswell Late 2013 - Unboxing & First Look'
#       processing video 'Nexus 5 : Unboxing and First Look (32GB White)'
#       processing video 'YouTube'
#       processing video 'iPhone 5C Green - Unboxing and First Look'
#       processing video 'GTA 5 Unboxing PS3 | Grand Theft Auto V UNBOXING Playstation 3'
#       processing video 'Nokia Lumia 925 Unboxing and Hands On - 32GB Black'
#       processing video 'First Look iPhone 5S Gold Champagne VS iPhone 5C and iPhone 5 Black Slate and White'
#       processing video 'Xbox One UNBOXING and FIRST LOOK!'
#       processing video 'SanDisk Ultra SDHC 30 Mb/s UNBOXING, REVIEW, DEMO and Set-up'
#       processing video 'Canon 600D DSLR Unboxing and First Look (July 2013)'
#       processing video 'Samsung Galaxy S4 Unboxing and DEMO!'
#       processing video 'Samsung Galaxy S3 Mini - UNBOXING and First Look'
#       processing video 'Samsung Galaxy Gio (S5660) Unboxing and Tour'
#
#     getting videos for playlist: Leaks & Rumors
#       processing video 'PS5 (2020) - 25 THINGS You DIDN'T Know!'
#       processing video 'iOS 14 & AirPods 3 - MAJOR Feature Leaks!'
#       processing video 'The Foldable iPhone (2021)'
#       processing video 'OnePlus 8 Pro – The S20 Ultra Killer?'
#       processing video 'iPhone 12 (2020) – 5 Models…Too Much?'
#       processing video 'PS5 (2020) - The Price Will Surprise You!'
#       processing video 'Why Apple Glasses are the NEXT iPhone!'
#       processing video 'PS5 & Xbox Series X – The Next Generation of Games!'
#       processing video 'Samsung Galaxy S20 - FINAL Leaks & Rumors!'
#       processing video 'Apple AirTag – Never Lose Anything Again!'
#       processing video 'Samsung Galaxy Z Flip - The FUTURE of Smartphones?'
#       processing video 'iPhone 12 (2020) and Beyond!'
#       processing video 'PS5 (2020) – Release Date, Games, Final Design, Controller & more!'
#       processing video 'iPhone 9 (2020) - But Why?'
#       processing video 'Samsung Galaxy S20 Ultra – Why I’m Concerned!'
#       processing video 'PS5 vs Xbox Series X (2020) – CPU, GPU & Graphics!'
#       processing video 'iPhone 12, Galaxy S20, PS5 & more – EPIC Tech for 2020!'
#       processing video 'iPhone 12 & iPhone SE 2 (2020) - What We Know!'
#       processing video 'PS5 vs Xbox Series X (2020)  - FULL Comparison!'
#       processing video '14" MacBook Pro (2020) - What We Know!'
#       processing video 'The 4 New iPhones for 2020!'
#       processing video 'PS5 - MAJOR Leaks Update - Price, Graphics & more!'
#       processing video 'PS5 - MAJOR Leaks Update - Price, Graphics & more!'
#       processing video 'THIS is the Samsung Galaxy S11'
#       processing video 'YouTube'
#       processing video 'Samsung Galaxy S11 (2020) - FULL Leaks & Rumors!'
#       processing video 'YouTube'
#       processing video 'YouTube'
#       processing video 'Apple AR Glasses (2020) - The NEXT iPhone!'
#       processing video 'What Is Happening with the 16" MacBook Pro?'
#       processing video 'PS5 (2020) - EXCLUSIVE First Look at Prototype 1'
#       processing video 'Google Pixel 4 - FINAL Leaks & Rumors!'
#       processing video 'PS5 (2020) - Revealed in Sony Patent!'
#       processing video 'iPhone 12 (2020) - The Return of the iPhone 4!'
#       processing video 'iPad Pro 4 (2019) - Early Preview!'
#       processing video 'NEW MacBook Pro 16" (2019) - Everything We Know!'
#       processing video 'Apple's Foldable iPhone - Everything We Know!'
#       processing video 'iPhone 11 Pro (2019) – FINAL Leaks & Rumors!'
#       processing video 'Apple Watch 5 (2019) - Everything We Know!'
#       processing video 'iPhone 11 Pro Leaks | Pixel 4 Hands-On | Note 10 Impressions & more -  ZONEofTECH NEWS #22'
#       processing video 'iPhone 11 (2019) & iPhone 12 (2020) - Release Date & Latest Leaks!'
#       processing video 'Samsung Galaxy Note 10 & Note 10 Plus - HANDS ON with Models'
#       processing video 'Samsung Galaxy Note 10 - FINAL Leaks & Rumors!'
#       processing video 'Samsung Galaxy Note 10 - FINAL Leaks & Rumors!'
#       processing video '2019 iPads - Everything We Know!'
#       processing video 'Google Watch - The FUTURE of Smartwatches?'
#       processing video 'iPhone 11 (2019) - FINAL Design PREVIEW!'
#       processing video 'YouTube'
#       processing video 'Samsung Galaxy S11 - The FUTURE of Smartphones!'
#       processing video 'The REAL 2019 MacBook Pro - Everything We Know!'
#       processing video 'YouTube'
#       processing video 'Google Pixel 4 (2019) - FINALLY a BIG Change!'
#       processing video 'PS5 vs Xbox 2 (2020) - The FULL Story!'
#       processing video 'Samsung Galaxy Note 10 (2019) - Everything We Know!'
#       processing video 'Apple's AR Glasses Will Change EVERYTHING!'
#       processing video 'PS5 (2020) – FULL SPECS Revealed!'
#       processing video 'iPhone 11 (2019) - HANDS ON with Case Models!'
#       processing video 'iOS 13, macOS Catalina & Mac Pro 2019 - ALL The Details!'
#       processing video 'iOS 13 - Everything We Know!'
#       processing video 'Apple WWDC 2019 – 7 Things to Expect!'
#       processing video 'The 3 NEW iPhones for 2019!'
#       processing video 'Galaxy Note 10 (2019) - Leaks & Rumors!'
#       processing video 'iPhone 2020 & Apple AR Glasses - The Future's Looking AMAZING!'
#       processing video 'THIS is the PS5!'
#       processing video 'THIS is the iPhone 11 (most likely)!'
#       processing video 'iOS 13 & WWDC 2019 - Everything to Expect!'
#       processing video 'OnePlus 7 - EVERYTHING We Know!'
#       processing video 'iPad Mini 5, iPad 2019 & iPad Air 3!'
#       processing video 'AirPods 2 (2019) - Everything We Know!'
#       processing video 'Google Pixel 4 (2019) - Leaks & Rumors!'
#       processing video 'Apple March 2019 Event - 7 Things to Expect!'
#       processing video 'MacBook Pro (2019) - Leaks & Rumors!'
#       processing video 'NEW Mac Pro & Apple 6K Display (2019)'
#       processing video 'iOS 13 LEAKED - Dark Mode is Coming!'
#       processing video 'Apple's Foldable iPhone (2020) - Everything We Know!'
#       processing video 'Google Watch - Leaks, Rumors & Everything We Know!'
#       processing video 'Samsung Galaxy S10 (2019) - FINAL Leaks & Rumors!'
#       processing video 'Samsung Galaxy X (2019) & the Future of Foldable Devices!'
#       processing video 'NEW iPod Touch (2019) - Actually Happening!'
#       processing video 'NEW iPad Mini 5 & 10 inch iPad (2019) - Everything You Need to Know!'
#       processing video 'THIS is the Samsung Galaxy S10!'
#       processing video 'Xbox 2 (2020) - The Future of Game Streaming!'
#       processing video 'iPhone 11 (2019) - The Most AMAZING Camera Yet!'
#       processing video 'iPhone 11, iPad Pro 4, iPad Mini 5, Mac Pro & more - 2019 Apple Tech!'
#       processing video 'iPhone 11 (2019) - LEAKED!'
#       processing video 'The 2019 iMac Redesign!'
#       processing video 'iPhone 11 (2019) -  Latest Leaks & Rumors!'
#       processing video 'S10 Plus - The Most INNOVATIVE Smartphone of 2019?'
#       processing video 'PS5 (2019) - The FUTURE of GAMING!'
#       processing video 'iPhone SE 2 - Is it STILL happening?'
#       processing video 'Samsung Galaxy S10 - FINALLY a Notchless Design?'
#       processing video '2019 iPhones - More POWERFUL than a Desktop PC?'
#       processing video 'Samsung's Foldable Galaxy X - HAS CHANGED EVERYTHING!'
#       processing video 'Samsung's Foldable Galaxy X - CONFIRMED!'
#       processing video 'iPad X (2018) - COMING TOMORROW!'
