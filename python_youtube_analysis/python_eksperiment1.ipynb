# %%
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
from youtube_data import youtube_search

# %%
test = youtube_search("Imagine Dragons")
test.keys()
# Out:
# dict_keys(['tags', 'channelId', 'channelTitle', 'categoryId', 'title', 'videoId', 'viewCount', 'likeCount', 'dislikeCount', 'commentCount', 'favoriteCount'])

# %%
test['commentCount'][:5]
# Out:
# ['34513', '43541', '127295', '407817', '305942']

# %%
df = pd.DataFrame(data=test)
df.head()
# Out:
#                                                 tags  \
# 0  [Imagine, Dragons, Birds, (Animated, Video), K...
# 1  [Imagine, Dragons, Bad, Liar, Kid, Ina, Korner...
# 2  [Imagine, Dragons, Natural, Kid, Ina, Korner, ...
# 3  [Imagine, Dragons, Believer, KIDinaKORNER/Inte...
# 4  [Imagine, Dragons, Thunder, KIDinaKORNER/Inter...
#
#                   channelId        channelTitle categoryId  \
# 0  UCpx_k19S2vUutWUUM9qmXEg  ImagineDragonsVEVO         10
# 1  UCpx_k19S2vUutWUUM9qmXEg  ImagineDragonsVEVO         10
# 2  UCpx_k19S2vUutWUUM9qmXEg  ImagineDragonsVEVO         10
# 3  UCpx_k19S2vUutWUUM9qmXEg  ImagineDragonsVEVO         10
# 4  UCpx_k19S2vUutWUUM9qmXEg  ImagineDragonsVEVO         10
#
#                                       title      videoId   viewCount  \
# 0  Imagine Dragons - Birds (Animated Video)  vOXZkm9p_zY    71237426
# 1                Imagine Dragons - Bad Liar  I-QfPUz1es8   122195002
# 2                 Imagine Dragons - Natural  0I647GU3Jsc   293729289
# 3                Imagine Dragons - Believer  7wtfhZwyrcc  1230019020
# 4                 Imagine Dragons - Thunder  fKopy74weus  1315625245
#
#   likeCount dislikeCount commentCount favoriteCount
# 0   1477521        17178        34513             0
# 1   1574580        32999        43541             0
# 2   3128313        69136       127295             0
# 3  10753851       301639       407817             0
# 4   7526860       376604       305942             0

# %%
df1 = df[['title','viewCount','channelTitle','commentCount','likeCount','dislikeCount','tags','favoriteCount','videoId','channelId','categoryId']]
df1.columns = ['Title','viewCount','channelTitle','commentCount','likeCount','dislikeCount','tags','favoriteCount','videoId','channelId','categoryId']
df1.head()
# Out:
#                                       Title   viewCount        channelTitle  \
# 0  Imagine Dragons - Birds (Animated Video)    71237426  ImagineDragonsVEVO
# 1                Imagine Dragons - Bad Liar   122195002  ImagineDragonsVEVO
# 2                 Imagine Dragons - Natural   293729289  ImagineDragonsVEVO
# 3                Imagine Dragons - Believer  1230019020  ImagineDragonsVEVO
# 4                 Imagine Dragons - Thunder  1315625245  ImagineDragonsVEVO
#
#   commentCount likeCount dislikeCount  \
# 0        34513   1477521        17178
# 1        43541   1574580        32999
# 2       127295   3128313        69136
# 3       407817  10753851       301639
# 4       305942   7526860       376604
#
#                                                 tags favoriteCount  \
# 0  [Imagine, Dragons, Birds, (Animated, Video), K...             0
# 1  [Imagine, Dragons, Bad, Liar, Kid, Ina, Korner...             0
# 2  [Imagine, Dragons, Natural, Kid, Ina, Korner, ...             0
# 3  [Imagine, Dragons, Believer, KIDinaKORNER/Inte...             0
# 4  [Imagine, Dragons, Thunder, KIDinaKORNER/Inter...             0
#
#        videoId                 channelId categoryId
# 0  vOXZkm9p_zY  UCpx_k19S2vUutWUUM9qmXEg         10
# 1  I-QfPUz1es8  UCpx_k19S2vUutWUUM9qmXEg         10
# 2  0I647GU3Jsc  UCpx_k19S2vUutWUUM9qmXEg         10
# 3  7wtfhZwyrcc  UCpx_k19S2vUutWUUM9qmXEg         10
# 4  fKopy74weus  UCpx_k19S2vUutWUUM9qmXEg         10

# %%
import numpy as np
numeric_dtype = ['viewCount','commentCount','likeCount','dislikeCount','favoriteCount']
for i in numeric_dtype:
    df1[i] = df[i].astype(int)

ImagineDragons = df1[df1['channelTitle']=='ImagineDragonsVEVO']
ImagineDragons.head()
# Out:
#                                       Title   viewCount        channelTitle  \
# 0  Imagine Dragons - Birds (Animated Video)    71237426  ImagineDragonsVEVO
# 1                Imagine Dragons - Bad Liar   122195002  ImagineDragonsVEVO
# 2                 Imagine Dragons - Natural   293729289  ImagineDragonsVEVO
# 3                Imagine Dragons - Believer  1230019020  ImagineDragonsVEVO
# 4                 Imagine Dragons - Thunder  1315625245  ImagineDragonsVEVO
#
#    commentCount  likeCount  dislikeCount  \
# 0         34513    1477521         17178
# 1         43541    1574580         32999
# 2        127295    3128313         69136
# 3        407817   10753851        301639
# 4        305942    7526860        376604
#
#                                                 tags  favoriteCount  \
# 0  [Imagine, Dragons, Birds, (Animated, Video), K...              0
# 1  [Imagine, Dragons, Bad, Liar, Kid, Ina, Korner...              0
# 2  [Imagine, Dragons, Natural, Kid, Ina, Korner, ...              0
# 3  [Imagine, Dragons, Believer, KIDinaKORNER/Inte...              0
# 4  [Imagine, Dragons, Thunder, KIDinaKORNER/Inter...              0
#
#        videoId                 channelId categoryId
# 0  vOXZkm9p_zY  UCpx_k19S2vUutWUUM9qmXEg         10
# 1  I-QfPUz1es8  UCpx_k19S2vUutWUUM9qmXEg         10
# 2  0I647GU3Jsc  UCpx_k19S2vUutWUUM9qmXEg         10
# 3  7wtfhZwyrcc  UCpx_k19S2vUutWUUM9qmXEg         10
# 4  fKopy74weus  UCpx_k19S2vUutWUUM9qmXEg         10

# %%
ImagineDragons = ImagineDragons.sort_values(ascending=False,by='viewCount')
plt.bar(range(ImagineDragons.shape[0]),ImagineDragons['viewCount'])
plt.xticks(range(ImagineDragons.shape[0]),ImagineDragons['Title'],rotation=90)
plt.ylabel('viewCount in 100 millions')

plt.show()
